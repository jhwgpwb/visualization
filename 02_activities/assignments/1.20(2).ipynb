# %% [markdown]
# Intended purpose for data visualization:
# 1.Persuading
# 2.Comparison
# 3.Evaluating
# 4.Exploring

# %% [markdown]
# Intended audience for data visualization:
# 1.Age
# 2.Education
# 3.Expertise
# 4.Accessibility

# %% [markdown]
# Intended medium
# 1.Print
# 2.Web
# 3.Poster
# 4.Presentation

# %% [markdown]
# Dataset types:
# 1.Tables
# 2.Networks
# 3.Fields
# 4.Geometries

# %% [markdown]
# Good vs. bad visualization: Cognitive load
# Online PowerBI dashboard
# Data visualization catalogue :https://datavizcatalogue.com/
